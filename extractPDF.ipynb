# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from cStringIO import StringIO

def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = file(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()
    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)
    fp.close()
    device.close()
    str = retstr.getvalue()
    retstr.close()
    return str

if __name__ == '__main__':
    words = convert_pdf_to_txt('992.pdf')
    print words
# Out:
# 課程大綱及進度表
#
# 開課系所
# 開課學年
# 開課學期
# 課程名稱(中文)
# 課程名稱(英文)
# 課程碼
# 分班碼
# 先修科目或先備能力
# 學分數
# 開課教師
# e-mail
# 電話
# Office Hours
# 課程概述(中文、英文)
# 本課程旨在介紹談判的理念、技巧及
# 如何運用談判解決衝突，創造雙贏。
#
# 教學目標
# 1. 了解談判的基本理念。
# 2. 認識談判與協商技巧。
# 3. 運用談判解決衝突。
#
# 授課課程大綱明細
# 1. 溝通、談判與協商理念介紹。
# 2. 談判基本型態與模式
# 3. 談判活動的流程
# 4. 談判前的準備工作
# 5. 擬訂談判計劃
# 6. 相關個案研討
# 7. 有效談判策略
# 8. 運用談判解決衝突
#
# 參考書目
# 1. 劉必榮(2006)著:學會談判,文經社
#
# 出版。
#
# 2. 張國忠(1999)編著:商業談判原理
#
# EMBA
# 99 學年度
# 第 2 學期
# 談判與協商
# Negotiation
#
#
# 無
# 1 學分
# 曾燦燈
# tdtseng9988@yahoo.com.tw
# 0937-568795、07-607-7773(0)
# 無
# The purpose of this course is to
# introduce the concept of negotiation,
# the negotiation skills and how to handle
# the conflict.
# 1. To understand the basic concept of
#
# negotiation.
#
# 2. To learn the negotiation skills.
# 3. To handle conflict through
#
# 1. The concept of communication and
#
# negotiation.
#
# negotiation.
#
# negotiation.
#
# 2. The basic style and model of
#
# 3. The process of negotiation.
# 4. How to prepare the negotiation?
# 5. How to set the negotiation planning?
# 6. Some cases study.
# 7. The negotiation stategies.
# 8. Handle conflict through negotiation.
# 1. Lewicki, R.F. etal.(1997).
# Essential of Negotiation.
# Irwin/Mcgraw-Hill.
#
# 與實務。前程企業管理有限公司
#
# 課程要求
# 1.學期結束前必須每位學員交一份”
# 學習檔案”(包括:上課內容簡介，每次
# 上課心得及在生活上的應用)
# 評量方式
# 1. 上課個案研討作業(團體成績)20%
# 2. 學期末學習檔案(個人成績)60%
# 3. 上課出席及表現 20%
# 課程網址
# 助教資訊
# 備註
#
#
# 1.Each student need wright “learning
# files”(including teaching notes and
# implications.)
#
# 1. Cases study: 20%
# 2. Learning files: 60%
# 3. Course performance 20%
